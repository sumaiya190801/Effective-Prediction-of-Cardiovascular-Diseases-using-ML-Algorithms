# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('framingham.csv')

# %%
data.head()
# Out:
#       Sex  age  education currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0    male   39        4.0            No         0.0     0.0                0
# 1  female   46        2.0            No         0.0     0.0                0
# 2    male   48        1.0           Yes        20.0     0.0                0
# 3  female   61        3.0           Yes        30.0     0.0                0
# 4  female   46        3.0           Yes        23.0     0.0                0
#
#    prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0       No    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0       No    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0       No    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1       No    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0       No    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
data.tail()
# Out:
#          Sex  age  education currentSmoker  cigsPerDay  BPMeds  \
# 4235  female   48        2.0           Yes        20.0     NaN
# 4236  female   44        1.0           Yes        15.0     0.0
# 4237  female   52        2.0            No         0.0     0.0
# 4238    male   40        3.0            No         0.0     0.0
# 4239  female   39        3.0           Yes        30.0     0.0
#
#       prevalentStroke  prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  \
# 4235                0             0       No    248.0  131.0   72.0  22.00
# 4236                0             0       No    210.0  126.5   87.0  19.16
# 4237                0             0       No    269.0  133.5   83.0  21.47
# 4238                0             1       No    185.0  141.0   98.0  25.60
# 4239                0             0       No    196.0  133.0   86.0  20.91
#
#       heartRate  glucose  TenYearCHD
# 4235       84.0     86.0           0
# 4236       86.0      NaN           0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Sex              4240 non-null   object
#  1   age              4240 non-null   int64
#  2   education        4135 non-null   float64
#  3   currentSmoker    4240 non-null   object
#  4   cigsPerDay       4211 non-null   float64
#  5   BPMeds           4187 non-null   float64
#  6   prevalentStroke  4240 non-null   int64
#  7   prevalentHyp     4240 non-null   int64
#  8   diabetes         4240 non-null   object
#  9   totChol          4190 non-null   float64
#  10  sysBP            4240 non-null   float64
#  11  diaBP            4240 non-null   float64
#  12  BMI              4221 non-null   float64
#  13  heartRate        4239 non-null   float64
#  14  glucose          3852 non-null   float64
#  15  TenYearCHD       4240 non-null   int64
# ...

# %%
data.describe()
# Out:
#                age    education   cigsPerDay       BPMeds  prevalentStroke  \
# count  4240.000000  4135.000000  4211.000000  4187.000000      4240.000000
# mean     49.580189     1.979444     9.005937     0.029615         0.005896
# std       8.572942     1.019791    11.922462     0.169544         0.076569
# min      32.000000     1.000000     0.000000     0.000000         0.000000
# 25%      42.000000     1.000000     0.000000     0.000000         0.000000
# 50%      49.000000     2.000000     0.000000     0.000000         0.000000
# 75%      56.000000     3.000000    20.000000     0.000000         0.000000
# max      70.000000     4.000000    70.000000     1.000000         1.000000
#
#        prevalentHyp      totChol        sysBP        diaBP          BMI  \
# count   4240.000000  4190.000000  4240.000000  4240.000000  4221.000000
# mean       0.310613   236.699523   132.354599    82.897759    25.800801
# std        0.462799    44.591284    22.033300    11.910394     4.079840
# ...

# %%
dummy1=pd.get_dummies(data['Sex'])

# %%
dummy1.head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       0     1
# 3       1     0
# 4       1     0

# %%
data2=pd.concat((data,dummy1),axis=1)

# %%
data2.head()
# Out:
#       Sex  age  education currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0    male   39        4.0            No         0.0     0.0                0
# 1  female   46        2.0            No         0.0     0.0                0
# 2    male   48        1.0           Yes        20.0     0.0                0
# 3  female   61        3.0           Yes        30.0     0.0                0
# 4  female   46        3.0           Yes        23.0     0.0                0
#
#    prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0       No    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0       No    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0       No    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1       No    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0       No    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD  female  male
# ...

# %%
data2=data2.drop(['Sex'],axis=1)

# %%
data2=data2.drop(['female'],axis=1)

# %%
data2.head()
# Out:
#    age  education currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0   39        4.0            No         0.0     0.0                0
# 1   46        2.0            No         0.0     0.0                0
# 2   48        1.0           Yes        20.0     0.0                0
# 3   61        3.0           Yes        30.0     0.0                0
# 4   46        3.0           Yes        23.0     0.0                0
#
#    prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0       No    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0       No    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0       No    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1       No    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0       No    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD  male
# 0           0     1
# 1           0     0
# 2           0     1
# ...

# %%
data2=data2.rename(columns={"male":"Sex"})

# %%
data2.tail()
# Out:
#       age  education currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 4235   48        2.0           Yes        20.0     NaN                0
# 4236   44        1.0           Yes        15.0     0.0                0
# 4237   52        2.0            No         0.0     0.0                0
# 4238   40        3.0            No         0.0     0.0                0
# 4239   39        3.0           Yes        30.0     0.0                0
#
#       prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 4235             0       No    248.0  131.0   72.0  22.00       84.0     86.0
# 4236             0       No    210.0  126.5   87.0  19.16       86.0      NaN
# 4237             0       No    269.0  133.5   83.0  21.47       80.0    107.0
# 4238             1       No    185.0  141.0   98.0  25.60       67.0     72.0
# 4239             0       No    196.0  133.0   86.0  20.91       85.0     80.0
#
#       TenYearCHD  Sex
# 4235           0    0
# ...

# %%
data2.describe()
# Out:
#                age    education   cigsPerDay       BPMeds  prevalentStroke  \
# count  4240.000000  4135.000000  4211.000000  4187.000000      4240.000000
# mean     49.580189     1.979444     9.005937     0.029615         0.005896
# std       8.572942     1.019791    11.922462     0.169544         0.076569
# min      32.000000     1.000000     0.000000     0.000000         0.000000
# 25%      42.000000     1.000000     0.000000     0.000000         0.000000
# 50%      49.000000     2.000000     0.000000     0.000000         0.000000
# 75%      56.000000     3.000000    20.000000     0.000000         0.000000
# max      70.000000     4.000000    70.000000     1.000000         1.000000
#
#        prevalentHyp      totChol        sysBP        diaBP          BMI  \
# count   4240.000000  4190.000000  4240.000000  4240.000000  4221.000000
# mean       0.310613   236.699523   132.354599    82.897759    25.800801
# std        0.462799    44.591284    22.033300    11.910394     4.079840
# ...

# %%
dummy2=pd.get_dummies(data['currentSmoker'])

# %%
dummy2.head()
# Out:
#    No  Yes
# 0   1    0
# 1   1    0
# 2   0    1
# 3   0    1
# 4   0    1

# %%
data=pd.concat((data2,dummy2),axis=1)

# %%
data.head()
# Out:
#    age  education currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0   39        4.0            No         0.0     0.0                0
# 1   46        2.0            No         0.0     0.0                0
# 2   48        1.0           Yes        20.0     0.0                0
# 3   61        3.0           Yes        30.0     0.0                0
# 4   46        3.0           Yes        23.0     0.0                0
#
#    prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0       No    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0       No    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0       No    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1       No    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0       No    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD  Sex  No  Yes
# 0           0    1   1    0
# 1           0    0   1    0
# ...

# %%
data=data.drop(['No'],axis=1)

# %%
data=data.drop(['currentSmoker'],axis=1)

# %%
data=data.rename(columns={"Yes":"currentSmoker"})

# %%
data.head()
# Out:
#    age  education  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp diabetes  \
# 0   39        4.0         0.0     0.0                0             0       No
# 1   46        2.0         0.0     0.0                0             0       No
# 2   48        1.0        20.0     0.0                0             0       No
# 3   61        3.0        30.0     0.0                0             1       No
# 4   46        3.0        23.0     0.0                0             0       No
#
#    totChol  sysBP  diaBP    BMI  heartRate  glucose  TenYearCHD  Sex  \
# 0    195.0  106.0   70.0  26.97       80.0     77.0           0    1
# 1    250.0  121.0   81.0  28.73       95.0     76.0           0    0
# 2    245.0  127.5   80.0  25.34       75.0     70.0           0    1
# 3    225.0  150.0   95.0  28.58       65.0    103.0           1    0
# 4    285.0  130.0   84.0  23.10       85.0     85.0           0    0
#
#    currentSmoker
# 0              0
# 1              0
# 2              1
# ...

# %%
dummy3=pd.get_dummies(data['diabetes'])

# %%
data=pd.concat([data,dummy3],axis=1)

# %%
data.head()
# Out:
#    age  education  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp diabetes  \
# 0   39        4.0         0.0     0.0                0             0       No
# 1   46        2.0         0.0     0.0                0             0       No
# 2   48        1.0        20.0     0.0                0             0       No
# 3   61        3.0        30.0     0.0                0             1       No
# 4   46        3.0        23.0     0.0                0             0       No
#
#    totChol  sysBP  diaBP    BMI  heartRate  glucose  TenYearCHD  Sex  \
# 0    195.0  106.0   70.0  26.97       80.0     77.0           0    1
# 1    250.0  121.0   81.0  28.73       95.0     76.0           0    0
# 2    245.0  127.5   80.0  25.34       75.0     70.0           0    1
# 3    225.0  150.0   95.0  28.58       65.0    103.0           1    0
# 4    285.0  130.0   84.0  23.10       85.0     85.0           0    0
#
#    currentSmoker  No  Yes
# 0              0   1    0
# 1              0   1    0
# ...

# %%
data=data.drop(['No'],axis=1)

# %%
data=data.drop(['diabetes'],axis=1)

# %%
data=data.rename(columns={'Yes':'diabetes'})

# %%
data.head()
# Out:
#    age  education  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  totChol  \
# 0   39        4.0         0.0     0.0                0             0    195.0
# 1   46        2.0         0.0     0.0                0             0    250.0
# 2   48        1.0        20.0     0.0                0             0    245.0
# 3   61        3.0        30.0     0.0                0             1    225.0
# 4   46        3.0        23.0     0.0                0             0    285.0
#
#    sysBP  diaBP    BMI  heartRate  glucose  TenYearCHD  Sex  currentSmoker  \
# 0  106.0   70.0  26.97       80.0     77.0           0    1              0
# 1  121.0   81.0  28.73       95.0     76.0           0    0              0
# 2  127.5   80.0  25.34       75.0     70.0           0    1              1
# 3  150.0   95.0  28.58       65.0    103.0           1    0              1
# 4  130.0   84.0  23.10       85.0     85.0           0    0              1
#
#    diabetes
# 0         0
# 1         0
# ...

# %%
data.describe()
# Out:
#                age    education   cigsPerDay       BPMeds  prevalentStroke  \
# count  4240.000000  4135.000000  4211.000000  4187.000000      4240.000000
# mean     49.580189     1.979444     9.005937     0.029615         0.005896
# std       8.572942     1.019791    11.922462     0.169544         0.076569
# min      32.000000     1.000000     0.000000     0.000000         0.000000
# 25%      42.000000     1.000000     0.000000     0.000000         0.000000
# 50%      49.000000     2.000000     0.000000     0.000000         0.000000
# 75%      56.000000     3.000000    20.000000     0.000000         0.000000
# max      70.000000     4.000000    70.000000     1.000000         1.000000
#
#        prevalentHyp      totChol        sysBP        diaBP          BMI  \
# count   4240.000000  4190.000000  4240.000000  4240.000000  4221.000000
# mean       0.310613   236.699523   132.354599    82.897759    25.800801
# std        0.462799    44.591284    22.033300    11.910394     4.079840
# ...

# %% [markdown]
# # Removal of Outliers using Boxplot

# %%
 data.shape
# Out:
# (4240, 16)

# %% [markdown]
# # Handling Missing Values

# %%
data.isnull().sum()
# Out:
# age                  0
# education          105
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# Sex                  0
# currentSmoker        0
# diabetes             0
# dtype: int64

# %%
data['education'].replace(np.NaN,data['education'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# age                  0
# education            0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# Sex                  0
# currentSmoker        0
# diabetes             0
# dtype: int64

# %%
data['cigsPerDay'].replace(np.NaN,data['cigsPerDay'].mean(),inplace=True)

# %%
data['BPMeds'].replace(np.NaN,data['BPMeds'].mean(),inplace=True)

# %%
data['totChol'].replace(np.NaN,data['totChol'].mean(),inplace=True)

# %%
data['BMI'].replace(np.NaN,data['BMI'].mean(),inplace=True)

# %%
data['glucose'].replace(np.NaN,data['glucose'].mean(),inplace=True)

# %%
data['heartRate'].replace(np.NaN,data['heartRate'].mean(),inplace=True)

# %%
data=data.drop(['glucose'],axis=1)

# %%
data.isnull().sum()
# Out:
# age                0
# education          0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# TenYearCHD         0
# Sex                0
# currentSmoker      0
# diabetes           0
# dtype: int64

# %%
data.head()
# Out:
#    age  education  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  totChol  \
# 0   39        4.0         0.0     0.0                0             0    195.0
# 1   46        2.0         0.0     0.0                0             0    250.0
# 2   48        1.0        20.0     0.0                0             0    245.0
# 3   61        3.0        30.0     0.0                0             1    225.0
# 4   46        3.0        23.0     0.0                0             0    285.0
#
#    sysBP  diaBP    BMI  heartRate  TenYearCHD  Sex  currentSmoker  diabetes
# 0  106.0   70.0  26.97       80.0           0    1              0         0
# 1  121.0   81.0  28.73       95.0           0    0              0         0
# 2  127.5   80.0  25.34       75.0           0    1              1         0
# 3  150.0   95.0  28.58       65.0           1    0              1         0
# 4  130.0   84.0  23.10       85.0           0    0              1         0

# %% [markdown]
# # Data Balancing using Synthetic Minority Over-sampling Technique(SMOTE)

# %%
data.TenYearCHD.value_counts()
# Out:
# 0    3596
# 1     644
# Name: TenYearCHD, dtype: int64

# %%
#x=data[data.columns.difference(['TenYearCHD'])]
x=data.drop(['TenYearCHD'], axis = 1)
y=data.TenYearCHD
x.head()
# Out:
#    age  education  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  totChol  \
# 0   39        4.0         0.0     0.0                0             0    195.0
# 1   46        2.0         0.0     0.0                0             0    250.0
# 2   48        1.0        20.0     0.0                0             0    245.0
# 3   61        3.0        30.0     0.0                0             1    225.0
# 4   46        3.0        23.0     0.0                0             0    285.0
#
#    sysBP  diaBP    BMI  heartRate  Sex  currentSmoker  diabetes
# 0  106.0   70.0  26.97       80.0    1              0         0
# 1  121.0   81.0  28.73       95.0    0              0         0
# 2  127.5   80.0  25.34       75.0    1              1         0
# 3  150.0   95.0  28.58       65.0    0              1         0
# 4  130.0   84.0  23.10       85.0    0              1         0

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
print (x_train.shape, y_train.shape)
print (x_test.shape, y_test.shape)
# Out:
# (3392, 14) (3392,)
# (848, 14) (848,)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier()

# %%
model.fit(x_train,y_train)
y_predict=model.predict(x_test)

# %%
pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_predict))
pd.crosstab(y_test,y_predict)
# Out:
# 0.8408018867924528
# col_0         0   1
# TenYearCHD
# 0           703  23
# 1           112  10

# %%
pip install imblearn
# Out:
# ...
#
# ...

# %%
from imblearn.over_sampling import SMOTE
smote=SMOTE()

# %%
x_smote_train,y_smote_train=smote.fit_resample(x_train.astype('float'),y_train)

# %%
from collections import Counter
print("Before applying SMOTE:",Counter(y_train))
print("After applying SMOTE:",Counter(y_smote_train))
# Out:
# Before applying SMOTE: Counter({0: 2870, 1: 522})
# After applying SMOTE: Counter({0: 2870, 1: 2870})

# %%
plt.figure(figsize=(15,15))
sns.heatmap(x_train.corr(), annot=True, linewidths=0.01)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
important_features = SelectKBest(score_func=chi2, k=14)
fit = important_features.fit(x,y)
data_scores = pd.DataFrame(fit.scores_)
data_columns = pd.DataFrame(x.columns)
feature_Scores = pd.concat([data_columns,data_scores],axis=1)
feature_Scores.columns = ['Attributes','Score']

# %%
featureScores = feature_Scores.sort_values(by='Score', ascending=False)
featureScores
# Out:
#          Attributes       Score
# 7             sysBP  727.935535
# 0               age  319.266019
# 6           totChol  235.502392
# 2        cigsPerDay  220.812679
# 8             diaBP  152.748563
# 5      prevalentHyp   92.048736
# 13         diabetes   39.144944
# 3            BPMeds   30.615014
# 11              Sex   18.899930
# 4   prevalentStroke   16.109887
# 9               BMI   15.227367
# 1         education    6.233112
# 10        heartRate    4.232372
# 12    currentSmoker    0.811334

# %%
data=data[['sysBP','age','totChol','cigsPerDay','diaBP','TenYearCHD']]

# %%
data.head()
# Out:
#    sysBP  age  totChol  cigsPerDay  diaBP  TenYearCHD
# 0  106.0   39    195.0         0.0   70.0           0
# 1  121.0   46    250.0         0.0   81.0           0
# 2  127.5   48    245.0        20.0   80.0           0
# 3  150.0   61    225.0        30.0   95.0           1
# 4  130.0   46    285.0        23.0   84.0           0

# %%
from sklearn.model_selection import train_test_split

y = data['TenYearCHD'] #target variable
X = data.drop(['TenYearCHD'], axis = 1) #features
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (3392, 5) (3392,)
# (848, 5) (848,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import datasets, linear_model
from imblearn.pipeline import Pipeline
from sklearn.svm import SVC
from imblearn.pipeline import Pipeline
from sklearn.model_selection import RepeatedStratifiedKFold
from numpy import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
import sklearn.linear_model as lm




lm = lm.LogisticRegression()
model = lm.fit(X_train, y_train)
over = SMOTE(sampling_strategy=0.1)
steps = [('over', over), ('model', model)]
pipeline = Pipeline(steps=steps)
X, y = make_classification(n_samples=10000, n_features=5, n_redundant=0,
	n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=1)
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=1)
scores = cross_val_score(pipeline, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
print('Mean ROC AUC: %.3f' % mean(scores))
# Out:
# Mean ROC AUC: 0.943

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix
#print(confusion_matrix(y_test, y_pred))
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred, normalize=True)
)
# Out:
# 0.7653301886792453

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred, normalize=True)
)
# Out:
# 0.8360849056603774

# %%
import pandas
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier

kfold = model_selection.KFold(n_splits=5)
estimators = []
model1 = LogisticRegression().fit(x_test,y_test)
estimators.append(('logistic', model1))
model2 = KNeighborsClassifier(n_neighbors=3)
estimators.append(('cart', model2))

ensemble = VotingClassifier(estimators)

over = SMOTE(sampling_strategy=0.1)
steps = [('over', over), ('model', ensemble)]
pipeline = Pipeline(steps=steps)


results = model_selection.cross_val_score(pipeline, X, y, cv=kfold)
print(results.mean())
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python38\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9916
